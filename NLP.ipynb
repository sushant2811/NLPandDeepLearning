# %% [markdown]
# #### Ref. Datacamp
#
# ### Regex 101

# %%
import re

# %%
myString = "Let's write RegEx!  Won't that be fun?  I sure think so.  Can you find 4 sentences?  Or perhaps, all 19 words?"

# %%
sentenceEndings = r"[!.?]"

# %% [markdown]
# Split myString on sentence endings and print the result

# %%
re.split(r"[!.?]", myString)
# Out:
# ["Let's write RegEx",
#  "  Won't that be fun",
#  '  I sure think so',
#  '  Can you find 4 sentences',
#  '  Or perhaps, all 19 words',
#  '']

# %% [markdown]
# Find all capitalized words in myString and print the result

# %%
re.findall(r"[A-Z]", myString)
# Out:
# ['L', 'R', 'E', 'W', 'I', 'C', 'O']

# %%
re.findall(r"[A-Z]\w", myString)
# Out:
# ['Le', 'Re', 'Ex', 'Wo', 'Ca', 'Or']

# %%
re.findall(r"[A-Z]\w+", myString)
# Out:
# ['Let', 'RegEx', 'Won', 'Can', 'Or']

# %% [markdown]
# Split myString on spaces and print the result

# %%
re.split(r"\s", myString)
# Out:
# ["Let's",
#  'write',
#  'RegEx!',
#  '',
#  "Won't",
#  'that',
#  'be',
#  'fun?',
#  '',
#  'I',
#  'sure',
#  'think',
#  'so.',
#  '',
#  'Can',
#  'you',
#  'find',
#  '4',
#  'sentences?',
#  '',
#  'Or',
#  'perhaps,',
#  'all',
#  '19',
#  'words?']

# %%
myString
# Out:
# "Let's write RegEx!  Won't that be fun?  I sure think so.  Can you find 4 sentences?  Or perhaps, all 19 words?"

# %%
re.split(r"\s+", myString)
# Out:
# ["Let's",
#  'write',
#  'RegEx!',
#  "Won't",
#  'that',
#  'be',
#  'fun?',
#  'I',
#  'sure',
#  'think',
#  'so.',
#  'Can',
#  'you',
#  'find',
#  '4',
#  'sentences?',
#  'Or',
#  'perhaps,',
#  'all',
#  '19',
#  'words?']

# %% [markdown]
# Find all digits in myString and print the result

# %%
re.findall(r"\d+", myString)
# Out:
# ['4', '19']

# %% [markdown]
# Note that there are only 2 digits in the sentences

# %% [markdown]
# **Tokenization**

# %%
with open('./datasetsNLP/grail.txt', 'r') as file:
    
    sceneOne = file.read()

# %%
sceneOne
# Out:
# "SCENE 1: [wind] [clop clop clop] \nKING ARTHUR: Whoa there!  [clop clop clop] \nSOLDIER #1: Halt!  Who goes there?\nARTHUR: It is I, Arthur, son of Uther Pendragon, from the castle of Camelot.  King of the Britons, defeator of the Saxons, sovereign of all England!\nSOLDIER #1: Pull the other one!\nARTHUR: I am, ...  and this is my trusty servant Patsy.  We have ridden the length and breadth of the land in search of knights who will join me in my court at Camelot.  I must speak with your lord and master.\nSOLDIER #1: What?  Ridden on a horse?\nARTHUR: Yes!\nSOLDIER #1: You're using coconuts!\nARTHUR: What?\nSOLDIER #1: You've got two empty halves of coconut and you're bangin' 'em together.\nARTHUR: So?  We have ridden since the snows of winter covered this land, through the kingdom of Mercea, through--\nSOLDIER #1: Where'd you get the coconuts?\nARTHUR: We found them.\nSOLDIER #1: Found them?  In Mercea?  The coconut's tropical!\nARTHUR: What do you mean?\nSOLDIER #1: Well, this is a
# ...

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
sentences = sent_tokenize(sceneOne)

# %%
sentences
# Out:
# ['SCENE 1: [wind] [clop clop clop] \nKING ARTHUR: Whoa there!',
#  '[clop clop clop] \nSOLDIER #1: Halt!',
#  'Who goes there?',
#  'ARTHUR: It is I, Arthur, son of Uther Pendragon, from the castle of Camelot.',
#  'King of the Britons, defeator of the Saxons, sovereign of all England!',
#  'SOLDIER #1: Pull the other one!',
#  'ARTHUR: I am, ...  and this is my trusty servant Patsy.',
#  'We have ridden the length and breadth of the land in search of knights who will join me in my court at Camelot.',
#  'I must speak with your lord and master.',
#  'SOLDIER #1: What?',
#  'Ridden on a horse?',
#  'ARTHUR: Yes!',
#  "SOLDIER #1: You're using coconuts!",
#  'ARTHUR: What?',
#  "SOLDIER #1: You've got two empty halves of coconut and you're bangin' 'em together.",
#  'ARTHUR: So?',
#  "We have ridden since the snows of winter covered this land, through the kingdom of Mercea, through--\nSOLDIER #1: Where'd you get the coconuts?",
#  'ARTHUR: We found them.',
# ...

# %%
uniqueTokens = set(word_tokenize(sceneOne))

# %%
uniqueTokens
# Out:
# {'clllank',
#  'suffered',
#  'executive',
#  'in',
#  'twenty',
#  'the',
#  'minutes',
#  'dictatorship',
#  'word',
#  'absolutely',
#  'Would',
#  'signifying',
#  'strange',
#  'weapon',
#  'Tower',
#  'legally',
#  'Lie',
#  'examine',
#  'Let',
#  'makes',
#  'haste',
#  'brave',
#  'certainly',
#  'gra',
#  'passed',
#  'traveller',
#  'unsingable',
#  'looks',
#  'advancing',
#  'shall',
#  'worried',
#  'government',
#  'idiom',
#  'clop',
#  'became',
#  'All',
#  'jam',
#  'return',
#  'blessing',
#  '14',
#  'you',
#  'think',
#  'grovel',
#  'lambs',
#  'trusty',
#  'doing',
#  'wounding',
#  'glad',
#  'worthy',
#  'Nothing',
#  'evil',
#  'made',
#  'Aaah',
#  'My',
#  'people',
#  'removed',
#  'side',
#  'seen',
#  'scholar',
#  'pulp',
#  'second',
#  'Away',
#  'Exactly',
#  'Will',
#  'angels',
#  'la',
#  'resting',
#  'nearly',
#  'taken',
#  'ounce',
#  'bird',
#  'watery',
#  'Loimbard',
#  'bravely',
#  'saved',
#  'than',
#  'occasion',
#  'worry',
# ...

# %% [markdown]
# Search for the first occurrence of "coconuts" in scene_one: match

# %%
match = re.search("coconuts", sceneOne)

# %%
match
# Out:
# <_sre.SRE_Match object; span=(580, 588), match='coconuts'>

# %%
match.start()
# Out:
# 580

# %%
match.end()
# Out:
# 588

# %%
sceneOne[580:588]
# Out:
# 'coconuts'

# %%
sceneOne[560:588]
# Out:
# "ER #1: You're using coconuts"

# %% [markdown]
# Write a regular expression to search for anything in square brackets

# %%
re.search(r"\[.*\]", sceneOne)
# Out:
# <_sre.SRE_Match object; span=(9, 32), match='[wind] [clop clop clop]'>

# %%
sentences[3]
# Out:
# 'ARTHUR: It is I, Arthur, son of Uther Pendragon, from the castle of Camelot.'

# %%
re.match(r"\w+:", sentences[3])
# Out:
# <_sre.SRE_Match object; span=(0, 7), match='ARTHUR:'>

# %%
re.match(r"[\w\s]+:", sentences[3])
# Out:
# <_sre.SRE_Match object; span=(0, 7), match='ARTHUR:'>

# %% [markdown]
# **Advanced tokenizer**

# %%
from nltk.tokenize import regexp_tokenize

# %%
string2 = "SOLDIER #1: Found them? In Mercea? The coconut's tropical!"

# %%
regexp_tokenize(string2, r"\w+(\?!)")
# Out:
# []

# %%
regexp_tokenize(string2, r"(\w+|#\d|\?|!)")
# Out:
# ['SOLDIER',
#  '#1',
#  'Found',
#  'them',
#  '?',
#  'In',
#  'Mercea',
#  '?',
#  'The',
#  'coconut',
#  's',
#  'tropical',
#  '!']

# %%
regexp_tokenize(string2, r"(#\d\w+\?!)")
# Out:
# []

# %%
regexp_tokenize(string2, r"\s+")
# Out:
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']

# %% [markdown]
# **Tweet tokenization**

# %%
from nltk.tokenize import regexp_tokenize
from nltk.tokenize import TweetTokenizer

# %%
tweets = ['This is the best #nlp exercise ive found online! #python',
 '#NLP is super fun! <3 #learning',
 'Thanks @datacamp :) #nlp #python']

# %% [markdown]
# Pattern that matches hashtag

# %%
regexp_tokenize(tweets[0], r"#\w+")
# Out:
# ['#nlp', '#python']

# %% [markdown]
# Pattern that matches hashtag and mentions

# %%
regexp_tokenize(tweets[-1], r"[#@\w+]")
# Out:
# ['T',
#  'h',
#  'a',
#  'n',
#  'k',
#  's',
#  '@',
#  'd',
#  'a',
#  't',
#  'a',
#  'c',
#  'a',
#  'm',
#  'p',
#  '#',
#  'n',
#  'l',
#  'p',
#  '#',
#  'p',
#  'y',
#  't',
#  'h',
#  'o',
#  'n']

# %%
regexp_tokenize(tweets[-1], r"[#@]\w+")
# Out:
# ['@datacamp', '#nlp', '#python']

# %%
regexp_tokenize(tweets[-1], r"[#|@]\w+")
# Out:
# ['@datacamp', '#nlp', '#python']

# %%
tknzr = TweetTokenizer()

# %%
tknzr.tokenize(tweets[0])
# Out:
# ['This',
#  'is',
#  'the',
#  'best',
#  '#nlp',
#  'exercise',
#  'ive',
#  'found',
#  'online',
#  '!',
#  '#python']

# %%
allTokens = [tknzr.tokenize(t) for t in tweets]

# %%
allTokens
# Out:
# [['This',
#   'is',
#   'the',
#   'best',
#   '#nlp',
#   'exercise',
#   'ive',
#   'found',
#   'online',
#   '!',
#   '#python'],
#  ['#NLP', 'is', 'super', 'fun', '!', '<3', '#learning'],
#  ['Thanks', '@datacamp', ':)', '#nlp', '#python']]

# %% [markdown]
# ** Non-ascii tokenization **

# %%
germanText = 'Wann gehen wir zum Pizza? 🍕 Und fährst du mit Über? 🚕'

# %%
allWords = word_tokenize(germanText)

# %%
allWords
# Out:
# ['Wann',
#  'gehen',
#  'wir',
#  'zum',
#  'Pizza',
#  '?',
#  '🍕',
#  'Und',
#  'fährst',
#  'du',
#  'mit',
#  'Über',
#  '?',
#  '🚕']

# %%
re.split(r"[\s+|?]", germanText)
# Out:
# ['Wann',
#  'gehen',
#  'wir',
#  'zum',
#  'Pizza',
#  '',
#  '🍕',
#  'Und',
#  'fährst',
#  'du',
#  'mit',
#  'Über',
#  '',
#  '🚕']

# %%
re.split(r"[\s+]", germanText)
# Out:
# ['Wann',
#  'gehen',
#  'wir',
#  'zum',
#  'Pizza?',
#  '🍕',
#  'Und',
#  'fährst',
#  'du',
#  'mit',
#  'Über?',
#  '🚕']

# %%
re.findall(r"\w+|[?]", germanText)
# Out:
# ['Wann',
#  'gehen',
#  'wir',
#  'zum',
#  'Pizza',
#  '?',
#  'Und',
#  'fährst',
#  'du',
#  'mit',
#  'Über',
#  '?']

# %%
allWords
# Out:
# ['Wann',
#  'gehen',
#  'wir',
#  'zum',
#  'Pizza',
#  '?',
#  '🍕',
#  'Und',
#  'fährst',
#  'du',
#  'mit',
#  'Über',
#  '?',
#  '🚕']

# %%
capitalWords = r"[A-ZÜ]\w+"

# %%
regexp_tokenize(germanText, capitalWords)
# Out:
# ['Wann', 'Pizza', 'Und', 'Über']

# %% [markdown]
# Unicode ranges for emoji are:
#
# ('\U0001F300'-'\U0001F5FF'), ('\U0001F600-\U0001F64F'), ('\U0001F680-\U0001F6FF'), and ('\u2600'-\u26FF-\u2700-\u27BF')

# %%
emoji = "['\U0001F300-\U0001F5FF'|'\U0001F600-\U0001F64F'|'\U0001F680-\U0001F6FF'|'\u2600-\u26FF\u2700-\u27BF']"

# %%
regexp_tokenize(germanText, emoji)
# Out:
# ['🍕', '🚕']
